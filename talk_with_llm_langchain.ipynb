# %%
import dotenv
from dotenv import load_dotenv

import os
load_dotenv()  # Load environment variables from .env file
open_ai_API_KWY = os.environ.get("OPENAI_API_KEY")  # Get the OpenAI API key from environment variables
print(f"end={open_ai_API_KWY}")
# Out:
# end=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

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
from langchain_openai import OpenAI
llmModel = OpenAI()

# %%
response = llmModel.invoke("who is modi ?")
print(response)
# Out:
# Narendra Modi is an Indian politician and the current Prime Minister of India. He has been in office since 2014 and is a member of the Bharatiya Janata Party (BJP). Prior to becoming Prime Minister, he served as the Chief Minister of Gujarat from 2001 to 2014. Modi is known for his economic policies and his strong leadership style. He is also a controversial figure, with some praising his leadership and others criticizing his policies and actions.

# %%
from langchain_openai import ChatOpenAI
llmModel = ChatOpenAI(model_name="gpt-3.5-turbo-0125")

# %%
response = llmModel.invoke("who is modi ?")
for chunk in response:
    print(chunk)
    print("----")
# Out:
# ('content', 'Narendra Modi is an Indian politician serving as the Prime Minister of India since 2014. He is a member of the Bharatiya Janata Party (BJP) and the Rashtriya Swayamsevak Sangh (RSS). Modi previously served as the Chief Minister of the Indian state of Gujarat from 2001 to 2014. He is known for his pro-business and pro-development policies, as well as his strong leadership style.')
# ----
# ('additional_kwargs', {})
# ----
# ('response_metadata', {'token_usage': {'completion_tokens': 92, 'prompt_tokens': 12, 'total_tokens': 104, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None})
# ----
# ('type', 'ai')
# ----
# ('name', None)
# ----
# ('id', 'run-f0d8d49a-699b-4e84-b129-ce1a02a7144b-0')
# ----
# ('example', False)
# ...

# %%
message = [
    (
        "system",
        """You are a history-only assistant.

You MUST answer questions related to history.

If the user's question is NOT related to history,
do NOT answer the question.
Instead respond exactly:
"I can only answer history-related questions."
"""
    ),
    ("user", "what is the formula for area of a circle?")
]

response = llmModel.invoke(message)

print(response.content)
print("----")
response.schema()
# Out:
# I can only answer history-related questions.
# ----
# {'title': 'AIMessage',
#  'description': 'Message from an AI.\n\nAIMessage is returned from a chat model as a response to a prompt.\n\nThis message represents the output of the model and consists of both\nthe raw output as returned by the model together standardized fields\n(e.g., tool calls, usage metadata) added by the LangChain framework.',
#  'type': 'object',
#  'properties': {'content': {'title': 'Content',
#    'anyOf': [{'type': 'string'},
#     {'type': 'array',
#      'items': {'anyOf': [{'type': 'string'}, {'type': 'object'}]}}]},
#   'additional_kwargs': {'title': 'Additional Kwargs', 'type': 'object'},
#   'response_metadata': {'title': 'Response Metadata', 'type': 'object'},
#   'type': {'title': 'Type', 'default': 'ai', 'enum': ['ai'], 'type': 'string'},
#   'name': {'title': 'Name', 'type': 'string'},
#   'id': {'title': 'Id', 'type': 'string'},
# ...

# %%
response.response_metadata
# Out:
# {'token_usage': {'completion_tokens': 8,
#   'prompt_tokens': 65,
#   'total_tokens': 73,
#   'completion_tokens_details': {'accepted_prediction_tokens': 0,
#    'audio_tokens': 0,
#    'reasoning_tokens': 0,
#    'rejected_prediction_tokens': 0},
#   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}},
#  'model_name': 'gpt-3.5-turbo-0125',
#  'system_fingerprint': None,
#  'finish_reason': 'stop',
#  'logprobs': None}
