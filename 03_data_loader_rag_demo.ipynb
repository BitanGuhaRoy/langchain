# %%
from dotenv import load_dotenv
load_dotenv()  # Load environment variables from .env file
# Out:
# True

# %% [markdown]
# # Data Loader

# %%
from langchain_community.document_loaders import PyPDFLoader
PdfTextLoader = PyPDFLoader("rag_data/rag_knowledge_dataset.pdf")
documents= PdfTextLoader.load()
print(f"Number of documents loaded: {len(documents)}")
for doc in documents:
    print(doc.page_content[:100])  # Print first 100 characters of each document
# Out:
# Number of documents loaded: 2
# Cloud Computing Knowledge Base
#  Synthetic dataset for RAG experimentation
# 1. What is Cloud Computing
# A cache stores frequently accessed data closer to the application so that repeated requests can be s

# %%
from langchain_community.document_loaders import UnstructuredHTMLLoader
HtmlTextLoader = UnstructuredHTMLLoader("./rag_data/rag_knowledge_dataset.html")
html_documents = HtmlTextLoader.load()
#print(f"Number of HTML documents loaded: {len(html_documents)}")

# %%
# Out:
# 5.3.0
